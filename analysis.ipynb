# %%
try:
    import yfinance as yf
except:
    # !pip install yfinance
    import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tickers =  ['BTC-USD', 'ETH-USD', 'BNB-USD' ]
df = yf.download(tickers=tickers, start='2020-01-01', end='2023-01-01')['Adj Close']
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
plt.scatter(df[['BTC-USD']], df.index)

# %%
# Get daily return
returns = df.pct_change().dropna()

# %%
returns.head()
# Out:
# Ticker       BNB-USD   BTC-USD   ETH-USD
# Date
# 2020-01-02 -0.048365 -0.029819 -0.025931
# 2020-01-03  0.048625  0.051452  0.053069
# 2020-01-04  0.016915  0.008955  0.006690
# 2020-01-05  0.015802  0.000089  0.008939
# 2020-01-06  0.060009  0.048291  0.058905

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2A8D-DDD9
#
#  Directory of C:\Users\PAVILION USER\OneDrive - University of Hertfordshire\ADS1 MODULE
#
# 02/21/2024  07:23 PM    <DIR>          .
# 02/21/2024  05:35 PM    <DIR>          ..
# 02/21/2024  03:50 AM    <DIR>          .ipynb_checkpoints
# 02/18/2024  09:49 PM           619,622 Basic Statistics and Statistical Graphs.ipynb
# 02/18/2024  02:35 PM    <DIR>          data
# 02/21/2024  03:50 AM           758,498 Introduction and Relational Graphs wk1- Solutions.ipynb
# 02/21/2024  03:43 AM           497,511 Reading Files and Categorical Graphs week2 - Solutions.ipynb
# 02/18/2024  01:28 PM            13,183 UK_cities.txt
# 02/21/2024  07:23 PM            49,555 Untitled.ipynb
# 02/21/2024  06:04 AM    <DIR>          week4
#                5 File(s)      1,938,369 bytes
#                5 Dir(s)  182,402,170,880 bytes free
